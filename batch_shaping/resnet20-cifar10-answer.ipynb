# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# define the SimpleNN mode;
class ResNet_Block(nn.Module):
    def __init__(self, in_chs, out_chs, strides):
        super(ResNet_Block, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=in_chs, out_channels=out_chs,
                      stride=strides, padding=1, kernel_size=3, bias=False),
            nn.BatchNorm2d(out_chs),
            nn.ReLU(True)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=out_chs, out_channels=out_chs,
                      stride=1, padding=1, kernel_size=3, bias=False),
            nn.BatchNorm2d(out_chs)
        )

        if in_chs != out_chs:
            self.id_mapping = nn.Sequential(
                nn.Conv2d(in_channels=in_chs, out_channels=out_chs,
                          stride=strides, padding=0, kernel_size=1, bias=False),
                nn.BatchNorm2d(out_chs))
        else:
            self.id_mapping = None
        self.final_activation = nn.ReLU(True)

    def forward(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        if self.id_mapping is not None:
            x_ = self.id_mapping(x)
        else:
            x_ = x
        return self.final_activation(x_ + out)

class ResNetCIFAR(nn.Module):
    def __init__(self, num_layers=20, num_stem_conv=32, config=(16, 32, 64)):
        super(ResNetCIFAR, self).__init__()
        self.num_layers = 20
        self.head_conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=num_stem_conv,
                      stride=1, padding=1, kernel_size=3, bias=False),
            nn.BatchNorm2d(num_stem_conv),
            nn.ReLU(True)
        )
        num_layers_per_stage = (num_layers - 2) // 6
        self.body_op = []
        num_inputs = num_stem_conv
        for i in range(len(config)):
            for j in range(num_layers_per_stage):
                if j == 0 and i != 0:
                    strides = 2
                else:
                    strides = 1
                self.body_op.append(ResNet_Block(num_inputs, config[i], strides))
                num_inputs = config[i]
        self.body_op = nn.Sequential(*self.body_op)
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.final_fc = nn.Linear(config[-1], 10)

    def forward(self, x):
        out = self.head_conv(x)
        out = self.body_op(out)
        self.features = self.avg_pool(out)
        self.feat_1d = self.features.mean(3).mean(2)
        return self.final_fc(self.feat_1d)

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms


#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
#############################################

# %% [markdown]
# **Answer**
#
#
# ToTensor() and Normalize() is enough in this question. ToTensor() transforms PIL images to torch.tensor, and the element's value will be in [0,1]. Normalize() normalizes the tensor to have zero mean and unit standard deviation.

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=TRAIN_BATCH_SIZE, # your code
    shuffle=True, # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=VAL_BATCH_SIZE, # your code
    shuffle=False, # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F21.zip
# Extracting ./data/cifar10_trainval_F21.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F21.zip
# Extracting ./data/cifar10_trainval_F21.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here

device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = ResNetCIFAR()
net = net.to(device)
if device == 'cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
    
#############################################
# Out:
# Train on GPU...

# %% [markdown]
# ## Step 4: Set up loss functions and Optimizers
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**. Be careful about the required inputs to the loss function. Are the inputs the logits or softmax probabilities?)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 5e-4

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(params=net.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
# Training a neural network usually repeats the following 3 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the output logits from the neural network. Compute the forward loss.**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 200

# learning rate decay policy
DECAY_EPOCHS = [100, 150]
DECAY = 0.1

# the folder where the trained model is saved
CHECKPOINT_PATH = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    # handle the learning rate scheduler.
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################
    
    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        train_loss += loss.item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            
            # count the number of correctly predicted samples in the current batch
            _, predicted = outputs.max(1)
            total_examples += predicted.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'resnet_new.h5'))
        
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.6531, Training accuracy: 0.3769
# Validation loss: 1.5094, Validation accuracy: 0.4570
# Saving ...
#
# Epoch 1:
# Training loss: 1.1627, Training accuracy: 0.5792
# Validation loss: 1.1588, Validation accuracy: 0.5938
# Saving ...
#
# Epoch 2:
# Training loss: 0.9388, Training accuracy: 0.6692
# Validation loss: 1.2093, Validation accuracy: 0.5898
#
# Epoch 3:
# Training loss: 0.8018, Training accuracy: 0.7211
# Validation loss: 1.0363, Validation accuracy: 0.6636
# Saving ...
#
# Epoch 4:
# Training loss: 0.7316, Training accuracy: 0.7470
# Validation loss: 0.8755, Validation accuracy: 0.7034
# Saving ...
#
# Epoch 5:
# Training loss: 0.6921, Training accuracy: 0.7600
# Validation loss: 0.9769, Validation accuracy: 0.6826
#
# Epoch 6:
# Training loss: 0.6559, Training accuracy: 0.7745
# Validation loss: 0.7304, Validation accuracy: 0.7574
# Saving ...
#
# Epoch 7:
# Training loss: 0.6258, Training accuracy: 0.7856
# Validation loss: 1.0829, Validation accuracy: 0.6606
#
# Epoch 8:
# Training loss: 0.6129, Training accuracy: 0.7903
# Validation loss: 0.8109, Validation accuracy: 0.7430
#
# Epoch 9:
# Training loss: 0.5921, Training accuracy: 0.7960
# Validation loss: 0.8147, Validation accuracy: 0.7398
#
# Epoch 10:
# Training loss: 0.5812, Training accuracy: 0.8006
# Validation loss: 0.7416, Validation accuracy: 0.7604
# Saving ...
#
# Epoch 11:
# Training loss: 0.5702, Training accuracy: 0.8021
# Validation loss: 0.5968, Validation accuracy: 0.7972
# Saving ...
#
# Epoch 12:
# Training loss: 0.5546, Training accuracy: 0.8102
# Validation loss: 0.6649, Validation accuracy: 0.7792
#
# Epoch 13:
# Training loss: 0.5450, Training accuracy: 0.8105
# Validation loss: 0.6772, Validation accuracy: 0.7784
#
# Epoch 14:
# Training loss: 0.5420, Training accuracy: 0.8128
# Validation loss: 0.5898, Validation accuracy: 0.8006
# Saving ...
#
# Epoch 15:
# Training loss: 0.5321, Training accuracy: 0.8172
# Validation loss: 0.6609, Validation accuracy: 0.7756
#
# Epoch 16:
# Training loss: 0.5322, Training accuracy: 0.8162
# Validation loss: 0.5759, Validation accuracy: 0.8074
# Saving ...
#
# Epoch 17:
# Training loss: 0.5201, Training accuracy: 0.8207
# Validation loss: 0.5954, Validation accuracy: 0.8100
# Saving ...
#
# Epoch 18:
# Training loss: 0.5186, Training accuracy: 0.8223
# Validation loss: 0.7387, Validation accuracy: 0.7490
#
# Epoch 19:
# Training loss: 0.5133, Training accuracy: 0.8238
# Validation loss: 0.7542, Validation accuracy: 0.7596
#
# Epoch 20:
# Training loss: 0.5030, Training accuracy: 0.8291
# Validation loss: 0.7180, Validation accuracy: 0.7676
#
# Epoch 21:
# Training loss: 0.5011, Training accuracy: 0.8287
# Validation loss: 0.6123, Validation accuracy: 0.7966
#
# Epoch 22:
# Training loss: 0.5016, Training accuracy: 0.8262
# Validation loss: 0.6312, Validation accuracy: 0.7944
#
# Epoch 23:
# Training loss: 0.4937, Training accuracy: 0.8289
# Validation loss: 0.8408, Validation accuracy: 0.7284
#
# Epoch 24:
# Training loss: 0.4968, Training accuracy: 0.8287
# Validation loss: 0.6427, Validation accuracy: 0.7840
#
# Epoch 25:
# Training loss: 0.4880, Training accuracy: 0.8325
# Validation loss: 0.6042, Validation accuracy: 0.8082
#
# Epoch 26:
# Training loss: 0.4845, Training accuracy: 0.8345
# Validation loss: 0.6931, Validation accuracy: 0.7802
#
# Epoch 27:
# Training loss: 0.4801, Training accuracy: 0.8328
# Validation loss: 0.6441, Validation accuracy: 0.7902
#
# Epoch 28:
# Training loss: 0.4738, Training accuracy: 0.8359
# Validation loss: 0.6175, Validation accuracy: 0.7954
#
# Epoch 29:
# Training loss: 0.4817, Training accuracy: 0.8365
# Validation loss: 0.7250, Validation accuracy: 0.7638
#
# Epoch 30:
# Training loss: 0.4735, Training accuracy: 0.8371
# Validation loss: 0.6075, Validation accuracy: 0.8006
#
# Epoch 31:
# Training loss: 0.4784, Training accuracy: 0.8355
# Validation loss: 0.7827, Validation accuracy: 0.7362
#
# Epoch 32:
# Training loss: 0.4674, Training accuracy: 0.8409
# Validation loss: 1.1521, Validation accuracy: 0.6786
#
# Epoch 33:
# Training loss: 0.4702, Training accuracy: 0.8371
# Validation loss: 0.6244, Validation accuracy: 0.8030
#
# Epoch 34:
# Training loss: 0.4669, Training accuracy: 0.8385
# Validation loss: 0.7020, Validation accuracy: 0.7744
#
# Epoch 35:
# Training loss: 0.4657, Training accuracy: 0.8388
# Validation loss: 0.8268, Validation accuracy: 0.7502
#
# Epoch 36:
# Training loss: 0.4605, Training accuracy: 0.8417
# Validation loss: 0.9515, Validation accuracy: 0.7106
#
# Epoch 37:
# Training loss: 0.4641, Training accuracy: 0.8407
# Validation loss: 0.8120, Validation accuracy: 0.7444
#
# Epoch 38:
# Training loss: 0.4543, Training accuracy: 0.8451
# Validation loss: 0.7301, Validation accuracy: 0.7676
#
# Epoch 39:
# Training loss: 0.4538, Training accuracy: 0.8446
# Validation loss: 0.5982, Validation accuracy: 0.7978
#
# Epoch 40:
# Training loss: 0.4567, Training accuracy: 0.8426
# Validation loss: 0.8312, Validation accuracy: 0.7384
#
# Epoch 41:
# Training loss: 0.4511, Training accuracy: 0.8448
# Validation loss: 0.8256, Validation accuracy: 0.7474
#
# Epoch 42:
# Training loss: 0.4545, Training accuracy: 0.8432
# Validation loss: 0.7021, Validation accuracy: 0.7722
#
# Epoch 43:
# Training loss: 0.4471, Training accuracy: 0.8464
# Validation loss: 0.7381, Validation accuracy: 0.7530
#
# Epoch 44:
# Training loss: 0.4487, Training accuracy: 0.8454
# Validation loss: 0.5561, Validation accuracy: 0.8170
# Saving ...
#
# Epoch 45:
# Training loss: 0.4423, Training accuracy: 0.8489
# Validation loss: 0.6092, Validation accuracy: 0.8066
#
# Epoch 46:
# Training loss: 0.4494, Training accuracy: 0.8443
# Validation loss: 0.7156, Validation accuracy: 0.7602
#
# Epoch 47:
# Training loss: 0.4524, Training accuracy: 0.8442
# Validation loss: 0.6145, Validation accuracy: 0.8026
#
# Epoch 48:
# Training loss: 0.4437, Training accuracy: 0.8458
# Validation loss: 0.6186, Validation accuracy: 0.7970
#
# Epoch 49:
# Training loss: 0.4399, Training accuracy: 0.8481
# Validation loss: 0.4806, Validation accuracy: 0.8358
# Saving ...
#
# Epoch 50:
# Training loss: 0.4457, Training accuracy: 0.8452
# Validation loss: 0.8769, Validation accuracy: 0.7474
#
# Epoch 51:
# Training loss: 0.4396, Training accuracy: 0.8488
# Validation loss: 0.5581, Validation accuracy: 0.8092
#
# Epoch 52:
# Training loss: 0.4420, Training accuracy: 0.8475
# Validation loss: 0.5921, Validation accuracy: 0.8010
#
# Epoch 53:
# Training loss: 0.4356, Training accuracy: 0.8501
# Validation loss: 0.6627, Validation accuracy: 0.7856
#
# Epoch 54:
# Training loss: 0.4467, Training accuracy: 0.8458
# Validation loss: 0.5452, Validation accuracy: 0.8168
#
# Epoch 55:
# Training loss: 0.4427, Training accuracy: 0.8476
# Validation loss: 0.6950, Validation accuracy: 0.7696
#
# Epoch 56:
# Training loss: 0.4392, Training accuracy: 0.8495
# Validation loss: 0.7838, Validation accuracy: 0.7488
#
# Epoch 57:
# Training loss: 0.4329, Training accuracy: 0.8511
# Validation loss: 0.6152, Validation accuracy: 0.8022
#
# Epoch 58:
# Training loss: 0.4397, Training accuracy: 0.8478
# Validation loss: 0.7833, Validation accuracy: 0.7622
#
# Epoch 59:
# Training loss: 0.4350, Training accuracy: 0.8509
# Validation loss: 0.5131, Validation accuracy: 0.8234
#
# Epoch 60:
# Training loss: 0.4401, Training accuracy: 0.8488
# Validation loss: 0.7030, Validation accuracy: 0.7722
#
# Epoch 61:
# Training loss: 0.4349, Training accuracy: 0.8492
# Validation loss: 0.7035, Validation accuracy: 0.7776
#
# Epoch 62:
# Training loss: 0.4342, Training accuracy: 0.8525
# Validation loss: 0.8527, Validation accuracy: 0.7378
#
# Epoch 63:
# Training loss: 0.4331, Training accuracy: 0.8514
# Validation loss: 0.6548, Validation accuracy: 0.7882
#
# Epoch 64:
# Training loss: 0.4310, Training accuracy: 0.8509
# Validation loss: 0.5391, Validation accuracy: 0.8212
#
# Epoch 65:
# Training loss: 0.4350, Training accuracy: 0.8510
# Validation loss: 0.6580, Validation accuracy: 0.7822
#
# Epoch 66:
# Training loss: 0.4299, Training accuracy: 0.8529
# Validation loss: 0.6469, Validation accuracy: 0.7826
#
# Epoch 67:
# Training loss: 0.4308, Training accuracy: 0.8516
# Validation loss: 0.5484, Validation accuracy: 0.8166
#
# Epoch 68:
# Training loss: 0.4289, Training accuracy: 0.8548
# Validation loss: 0.5978, Validation accuracy: 0.8016
#
# Epoch 69:
# Training loss: 0.4311, Training accuracy: 0.8499
# Validation loss: 0.6522, Validation accuracy: 0.7894
#
# Epoch 70:
# Training loss: 0.4254, Training accuracy: 0.8537
# Validation loss: 0.5444, Validation accuracy: 0.8226
#
# Epoch 71:
# Training loss: 0.4322, Training accuracy: 0.8515
# Validation loss: 0.5169, Validation accuracy: 0.8288
#
# Epoch 72:
# Training loss: 0.4263, Training accuracy: 0.8537
# Validation loss: 0.4901, Validation accuracy: 0.8372
# Saving ...
#
# Epoch 73:
# Training loss: 0.4277, Training accuracy: 0.8523
# Validation loss: 0.4918, Validation accuracy: 0.8416
# Saving ...
#
# Epoch 74:
# Training loss: 0.4230, Training accuracy: 0.8534
# Validation loss: 0.6364, Validation accuracy: 0.7868
#
# Epoch 75:
# Training loss: 0.4286, Training accuracy: 0.8533
# Validation loss: 0.5182, Validation accuracy: 0.8264
#
# Epoch 76:
# Training loss: 0.4297, Training accuracy: 0.8515
# Validation loss: 0.5420, Validation accuracy: 0.8230
#
# Epoch 77:
# Training loss: 0.4257, Training accuracy: 0.8517
# Validation loss: 0.7815, Validation accuracy: 0.7740
#
# Epoch 78:
# Training loss: 0.4299, Training accuracy: 0.8528
# Validation loss: 0.5504, Validation accuracy: 0.8252
#
# Epoch 79:
# Training loss: 0.4234, Training accuracy: 0.8547
# Validation loss: 0.6280, Validation accuracy: 0.7926
#
# Epoch 80:
# Training loss: 0.4254, Training accuracy: 0.8544
# Validation loss: 0.6538, Validation accuracy: 0.8028
#
# Epoch 81:
# Training loss: 0.4217, Training accuracy: 0.8543
# Validation loss: 0.6966, Validation accuracy: 0.7782
#
# Epoch 82:
# Training loss: 0.4278, Training accuracy: 0.8538
# Validation loss: 0.7868, Validation accuracy: 0.7594
#
# Epoch 83:
# Training loss: 0.4255, Training accuracy: 0.8539
# Validation loss: 0.7470, Validation accuracy: 0.7616
#
# Epoch 84:
# Training loss: 0.4223, Training accuracy: 0.8547
# Validation loss: 0.5447, Validation accuracy: 0.8144
#
# Epoch 85:
# Training loss: 0.4207, Training accuracy: 0.8559
# Validation loss: 0.8594, Validation accuracy: 0.7368
#
# Epoch 86:
# Training loss: 0.4260, Training accuracy: 0.8526
# Validation loss: 0.6606, Validation accuracy: 0.7928
#
# Epoch 87:
# Training loss: 0.4212, Training accuracy: 0.8548
# Validation loss: 0.5932, Validation accuracy: 0.8102
#
# Epoch 88:
# Training loss: 0.4208, Training accuracy: 0.8542
# Validation loss: 0.5870, Validation accuracy: 0.8036
#
# Epoch 89:
# Training loss: 0.4264, Training accuracy: 0.8512
# Validation loss: 0.5080, Validation accuracy: 0.8274
#
# Epoch 90:
# Training loss: 0.4137, Training accuracy: 0.8570
# Validation loss: 0.5510, Validation accuracy: 0.8198
#
# Epoch 91:
# Training loss: 0.4180, Training accuracy: 0.8561
# Validation loss: 0.5539, Validation accuracy: 0.8152
#
# Epoch 92:
# Training loss: 0.4198, Training accuracy: 0.8564
# Validation loss: 0.9733, Validation accuracy: 0.7138
#
# Epoch 93:
# Training loss: 0.4235, Training accuracy: 0.8552
# Validation loss: 0.5725, Validation accuracy: 0.8104
#
# Epoch 94:
# Training loss: 0.4198, Training accuracy: 0.8554
# Validation loss: 0.6253, Validation accuracy: 0.7976
#
# Epoch 95:
# Training loss: 0.4247, Training accuracy: 0.8539
# Validation loss: 0.4548, Validation accuracy: 0.8456
# Saving ...
#
# Epoch 96:
# Training loss: 0.4245, Training accuracy: 0.8532
# Validation loss: 0.5987, Validation accuracy: 0.8016
#
# Epoch 97:
# Training loss: 0.4221, Training accuracy: 0.8541
# Validation loss: 0.6438, Validation accuracy: 0.7946
#
# Epoch 98:
# Training loss: 0.4214, Training accuracy: 0.8562
# Validation loss: 0.7101, Validation accuracy: 0.7702
#
# Epoch 99:
# Training loss: 0.4166, Training accuracy: 0.8569
# Validation loss: 0.6802, Validation accuracy: 0.7860
#
# Current learning rate has decayed to 0.010000
# Epoch 100:
# Training loss: 0.2718, Training accuracy: 0.9087
# Validation loss: 0.2971, Validation accuracy: 0.8974
# Saving ...
#
# Epoch 101:
# Training loss: 0.2238, Training accuracy: 0.9244
# Validation loss: 0.2847, Validation accuracy: 0.9030
# Saving ...
#
# Epoch 102:
# Training loss: 0.2036, Training accuracy: 0.9304
# Validation loss: 0.2806, Validation accuracy: 0.9022
#
# Epoch 103:
# Training loss: 0.1944, Training accuracy: 0.9337
# Validation loss: 0.2824, Validation accuracy: 0.9046
# Saving ...
#
# Epoch 104:
# Training loss: 0.1847, Training accuracy: 0.9375
# Validation loss: 0.2832, Validation accuracy: 0.9042
#
# Epoch 105:
# Training loss: 0.1743, Training accuracy: 0.9405
# Validation loss: 0.2713, Validation accuracy: 0.9090
# Saving ...
#
# Epoch 106:
# Training loss: 0.1686, Training accuracy: 0.9426
# Validation loss: 0.2677, Validation accuracy: 0.9104
# Saving ...
#
# Epoch 107:
# Training loss: 0.1605, Training accuracy: 0.9459
# Validation loss: 0.2965, Validation accuracy: 0.9030
#
# Epoch 108:
# Training loss: 0.1572, Training accuracy: 0.9449
# Validation loss: 0.2835, Validation accuracy: 0.9082
#
# Epoch 109:
# Training loss: 0.1516, Training accuracy: 0.9479
# Validation loss: 0.2861, Validation accuracy: 0.9066
#
# Epoch 110:
# Training loss: 0.1470, Training accuracy: 0.9497
# Validation loss: 0.2900, Validation accuracy: 0.9072
#
# Epoch 111:
# Training loss: 0.1435, Training accuracy: 0.9501
# Validation loss: 0.2808, Validation accuracy: 0.9120
# Saving ...
#
# Epoch 112:
# Training loss: 0.1380, Training accuracy: 0.9539
# Validation loss: 0.2865, Validation accuracy: 0.9092
#
# Epoch 113:
# Training loss: 0.1342, Training accuracy: 0.9535
# Validation loss: 0.3171, Validation accuracy: 0.8988
#
# Epoch 114:
# Training loss: 0.1341, Training accuracy: 0.9547
# Validation loss: 0.2798, Validation accuracy: 0.9094
#
# Epoch 115:
# Training loss: 0.1309, Training accuracy: 0.9551
# Validation loss: 0.2874, Validation accuracy: 0.9036
#
# Epoch 116:
# Training loss: 0.1324, Training accuracy: 0.9544
# Validation loss: 0.3192, Validation accuracy: 0.9012
#
# Epoch 117:
# Training loss: 0.1264, Training accuracy: 0.9566
# Validation loss: 0.2973, Validation accuracy: 0.9088
#
# Epoch 118:
# Training loss: 0.1281, Training accuracy: 0.9559
# Validation loss: 0.2963, Validation accuracy: 0.9108
#
# Epoch 119:
# Training loss: 0.1250, Training accuracy: 0.9574
# Validation loss: 0.3251, Validation accuracy: 0.9048
#
# Epoch 120:
# Training loss: 0.1247, Training accuracy: 0.9582
# Validation loss: 0.3130, Validation accuracy: 0.9022
#
# Epoch 121:
# Training loss: 0.1242, Training accuracy: 0.9585
# Validation loss: 0.3170, Validation accuracy: 0.9018
#
# Epoch 122:
# Training loss: 0.1228, Training accuracy: 0.9584
# Validation loss: 0.3166, Validation accuracy: 0.9010
#
# Epoch 123:
# Training loss: 0.1226, Training accuracy: 0.9578
# Validation loss: 0.2950, Validation accuracy: 0.9086
#
# Epoch 124:
# Training loss: 0.1191, Training accuracy: 0.9590
# Validation loss: 0.3240, Validation accuracy: 0.9010
#
# Epoch 125:
# Training loss: 0.1223, Training accuracy: 0.9576
# Validation loss: 0.3177, Validation accuracy: 0.9048
#
# Epoch 126:
# Training loss: 0.1192, Training accuracy: 0.9588
# Validation loss: 0.3209, Validation accuracy: 0.9000
#
# Epoch 127:
# Training loss: 0.1217, Training accuracy: 0.9577
# Validation loss: 0.3333, Validation accuracy: 0.8976
#
# Epoch 128:
# Training loss: 0.1211, Training accuracy: 0.9589
# Validation loss: 0.3263, Validation accuracy: 0.9002
#
# Epoch 129:
# Training loss: 0.1238, Training accuracy: 0.9580
# Validation loss: 0.3238, Validation accuracy: 0.9010
#
# Epoch 130:
# Training loss: 0.1207, Training accuracy: 0.9584
# Validation loss: 0.3377, Validation accuracy: 0.8986
#
# Epoch 131:
# Training loss: 0.1204, Training accuracy: 0.9585
# Validation loss: 0.3475, Validation accuracy: 0.8952
#
# Epoch 132:
# Training loss: 0.1206, Training accuracy: 0.9585
# Validation loss: 0.3242, Validation accuracy: 0.8994
#
# Epoch 133:
# Training loss: 0.1207, Training accuracy: 0.9586
# Validation loss: 0.3387, Validation accuracy: 0.8956
#
# Epoch 134:
# Training loss: 0.1237, Training accuracy: 0.9574
# Validation loss: 0.3654, Validation accuracy: 0.8912
#
# Epoch 135:
# Training loss: 0.1231, Training accuracy: 0.9585
# Validation loss: 0.3712, Validation accuracy: 0.8910
#
# Epoch 136:
# Training loss: 0.1255, Training accuracy: 0.9572
# Validation loss: 0.3757, Validation accuracy: 0.8868
#
# Epoch 137:
# Training loss: 0.1213, Training accuracy: 0.9583
# Validation loss: 0.3594, Validation accuracy: 0.8926
#
# Epoch 138:
# Training loss: 0.1229, Training accuracy: 0.9580
# Validation loss: 0.3543, Validation accuracy: 0.8950
#
# Epoch 139:
# Training loss: 0.1232, Training accuracy: 0.9574
# Validation loss: 0.3594, Validation accuracy: 0.8984
#
# Epoch 140:
# Training loss: 0.1199, Training accuracy: 0.9592
# Validation loss: 0.3213, Validation accuracy: 0.8962
#
# Epoch 141:
# Training loss: 0.1238, Training accuracy: 0.9569
# Validation loss: 0.3202, Validation accuracy: 0.9066
#
# Epoch 142:
# Training loss: 0.1236, Training accuracy: 0.9569
# Validation loss: 0.3816, Validation accuracy: 0.8886
#
# Epoch 143:
# Training loss: 0.1228, Training accuracy: 0.9584
# Validation loss: 0.3350, Validation accuracy: 0.8962
#
# Epoch 144:
# Training loss: 0.1235, Training accuracy: 0.9572
# Validation loss: 0.3553, Validation accuracy: 0.8914
#
# Epoch 145:
# Training loss: 0.1197, Training accuracy: 0.9598
# Validation loss: 0.3373, Validation accuracy: 0.8966
#
# Epoch 146:
# Training loss: 0.1211, Training accuracy: 0.9581
# Validation loss: 0.3248, Validation accuracy: 0.9016
#
# Epoch 147:
# Training loss: 0.1227, Training accuracy: 0.9579
# Validation loss: 0.3467, Validation accuracy: 0.8946
#
# Epoch 148:
# Training loss: 0.1223, Training accuracy: 0.9579
# Validation loss: 0.3504, Validation accuracy: 0.8926
#
# Epoch 149:
# Training loss: 0.1288, Training accuracy: 0.9554
# Validation loss: 0.4007, Validation accuracy: 0.8872
#
# Current learning rate has decayed to 0.001000
# Epoch 150:
# Training loss: 0.0827, Training accuracy: 0.9731
# Validation loss: 0.2756, Validation accuracy: 0.9180
# Saving ...
#
# Epoch 151:
# Training loss: 0.0653, Training accuracy: 0.9803
# Validation loss: 0.2692, Validation accuracy: 0.9154
#
# Epoch 152:
# Training loss: 0.0584, Training accuracy: 0.9834
# Validation loss: 0.2663, Validation accuracy: 0.9192
# Saving ...
#
# Epoch 153:
# Training loss: 0.0546, Training accuracy: 0.9841
# Validation loss: 0.2686, Validation accuracy: 0.9168
#
# Epoch 154:
# Training loss: 0.0522, Training accuracy: 0.9855
# Validation loss: 0.2683, Validation accuracy: 0.9182
#
# Epoch 155:
# Training loss: 0.0475, Training accuracy: 0.9877
# Validation loss: 0.2719, Validation accuracy: 0.9186
#
# Epoch 156:
# Training loss: 0.0457, Training accuracy: 0.9879
# Validation loss: 0.2723, Validation accuracy: 0.9190
#
# Epoch 157:
# Training loss: 0.0463, Training accuracy: 0.9875
# Validation loss: 0.2695, Validation accuracy: 0.9184
#
# Epoch 158:
# Training loss: 0.0439, Training accuracy: 0.9884
# Validation loss: 0.2704, Validation accuracy: 0.9194
# Saving ...
#
# Epoch 159:
# Training loss: 0.0435, Training accuracy: 0.9889
# Validation loss: 0.2689, Validation accuracy: 0.9200
# Saving ...
#
# Epoch 160:
# Training loss: 0.0417, Training accuracy: 0.9892
# Validation loss: 0.2673, Validation accuracy: 0.9204
# Saving ...
#
# Epoch 161:
# Training loss: 0.0423, Training accuracy: 0.9887
# Validation loss: 0.2711, Validation accuracy: 0.9216
# Saving ...
#
# Epoch 162:
# Training loss: 0.0399, Training accuracy: 0.9896
# Validation loss: 0.2740, Validation accuracy: 0.9184
#
# Epoch 163:
# Training loss: 0.0387, Training accuracy: 0.9902
# Validation loss: 0.2734, Validation accuracy: 0.9178
#
# Epoch 164:
# Training loss: 0.0368, Training accuracy: 0.9908
# Validation loss: 0.2691, Validation accuracy: 0.9190
#
# Epoch 165:
# Training loss: 0.0368, Training accuracy: 0.9910
# Validation loss: 0.2744, Validation accuracy: 0.9178
#
# Epoch 166:
# Training loss: 0.0368, Training accuracy: 0.9910
# Validation loss: 0.2736, Validation accuracy: 0.9178
#
# Epoch 167:
# Training loss: 0.0363, Training accuracy: 0.9911
# Validation loss: 0.2763, Validation accuracy: 0.9162
#
# Epoch 168:
# Training loss: 0.0349, Training accuracy: 0.9916
# Validation loss: 0.2739, Validation accuracy: 0.9188
#
# Epoch 169:
# Training loss: 0.0350, Training accuracy: 0.9914
# Validation loss: 0.2739, Validation accuracy: 0.9200
#
# Epoch 170:
# Training loss: 0.0344, Training accuracy: 0.9918
# Validation loss: 0.2773, Validation accuracy: 0.9174
#
# Epoch 171:
# Training loss: 0.0326, Training accuracy: 0.9927
# Validation loss: 0.2810, Validation accuracy: 0.9184
#
# Epoch 172:
# Training loss: 0.0314, Training accuracy: 0.9930
# Validation loss: 0.2804, Validation accuracy: 0.9178
#
# Epoch 173:
# Training loss: 0.0325, Training accuracy: 0.9923
# Validation loss: 0.2779, Validation accuracy: 0.9166
#
# Epoch 174:
# Training loss: 0.0302, Training accuracy: 0.9932
# Validation loss: 0.2826, Validation accuracy: 0.9190
#
# Epoch 175:
# Training loss: 0.0314, Training accuracy: 0.9925
# Validation loss: 0.2844, Validation accuracy: 0.9160
#
# Epoch 176:
# Training loss: 0.0307, Training accuracy: 0.9932
# Validation loss: 0.2830, Validation accuracy: 0.9154
#
# Epoch 177:
# Training loss: 0.0311, Training accuracy: 0.9925
# Validation loss: 0.2812, Validation accuracy: 0.9170
#
# Epoch 178:
# Training loss: 0.0301, Training accuracy: 0.9931
# Validation loss: 0.2850, Validation accuracy: 0.9154
#
# Epoch 179:
# Training loss: 0.0300, Training accuracy: 0.9933
# Validation loss: 0.2835, Validation accuracy: 0.9170
#
# Epoch 180:
# Training loss: 0.0293, Training accuracy: 0.9934
# Validation loss: 0.2823, Validation accuracy: 0.9182
#
# Epoch 181:
# Training loss: 0.0296, Training accuracy: 0.9932
# Validation loss: 0.2861, Validation accuracy: 0.9178
#
# Epoch 182:
# Training loss: 0.0295, Training accuracy: 0.9933
# Validation loss: 0.2851, Validation accuracy: 0.9184
#
# Epoch 183:
# Training loss: 0.0282, Training accuracy: 0.9937
# Validation loss: 0.2837, Validation accuracy: 0.9190
#
# Epoch 184:
# Training loss: 0.0280, Training accuracy: 0.9936
# Validation loss: 0.2839, Validation accuracy: 0.9182
#
# Epoch 185:
# Training loss: 0.0282, Training accuracy: 0.9937
# Validation loss: 0.2894, Validation accuracy: 0.9150
#
# Epoch 186:
# Training loss: 0.0273, Training accuracy: 0.9943
# Validation loss: 0.2872, Validation accuracy: 0.9172
#
# Epoch 187:
# Training loss: 0.0280, Training accuracy: 0.9934
# Validation loss: 0.2870, Validation accuracy: 0.9188
#
# Epoch 188:
# Training loss: 0.0264, Training accuracy: 0.9944
# Validation loss: 0.2849, Validation accuracy: 0.9178
#
# Epoch 189:
# Training loss: 0.0262, Training accuracy: 0.9940
# Validation loss: 0.2878, Validation accuracy: 0.9178
#
# Epoch 190:
# Training loss: 0.0259, Training accuracy: 0.9943
# Validation loss: 0.2868, Validation accuracy: 0.9160
#
# Epoch 191:
# Training loss: 0.0257, Training accuracy: 0.9942
# Validation loss: 0.2877, Validation accuracy: 0.9182
#
# Epoch 192:
# Training loss: 0.0261, Training accuracy: 0.9943
# Validation loss: 0.2914, Validation accuracy: 0.9168
#
# Epoch 193:
# Training loss: 0.0251, Training accuracy: 0.9944
# Validation loss: 0.2891, Validation accuracy: 0.9162
#
# Epoch 194:
# Training loss: 0.0259, Training accuracy: 0.9944
# Validation loss: 0.2860, Validation accuracy: 0.9188
#
# Epoch 195:
# Training loss: 0.0258, Training accuracy: 0.9942
# Validation loss: 0.2896, Validation accuracy: 0.9186
#
# Epoch 196:
# Training loss: 0.0253, Training accuracy: 0.9943
# Validation loss: 0.2907, Validation accuracy: 0.9170
#
# Epoch 197:
# Training loss: 0.0242, Training accuracy: 0.9947
# Validation loss: 0.2900, Validation accuracy: 0.9206
#
# Epoch 198:
# Training loss: 0.0238, Training accuracy: 0.9950
# Validation loss: 0.2868, Validation accuracy: 0.9214
#
# Epoch 199:
# Training loss: 0.0249, Training accuracy: 0.9947
# Validation loss: 0.2937, Validation accuracy: 0.9170
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9216

# %% [markdown]
# ## Save predictions on test data

# %%
from tools.dataset import CIFAR10

net = ResNetCIFAR()
chkpnt = torch.load('./saved_model/resnet_new.h5')
net.load_state_dict(chkpnt['net'])
net.cuda()
net.eval()

test_set = CIFAR10(
    root=DATA_ROOT, 
    mode='test', 
    transform=transform_val
)

# do NOT shuffle your test data loader
# otherwise the order of samples will be messed up
# and your test accuracy is likely to drop to random guessing level
test_loader = DataLoader(
    test_set, batch_size=200, shuffle=False, num_workers=1)

results = []
with torch.no_grad():
    for x in test_loader:
        y = net(x.cuda()).argmax(1).cpu()
        results.append(y)
    
results = torch.cat(results)
if isinstance(results, torch.Tensor):
    results = results.cpu().numpy()
    
with open('predictions.csv', 'w') as fp:
    fp.write("Id,Label\n")
    for i in range(len(results)):
        fp.write("%d,%d\n" %(i, results[i]))
# Out:
# Using downloaded and verified file: ./data/cifar10_test_F21.zip
# Extracting ./data/cifar10_test_F21.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Our baseline test acc
#
# **0.9183**
