# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# define the SimpleNN mode;
class ResNet_Block(nn.Module):
    def __init__(self, in_chs, out_chs, strides):
        super(ResNet_Block, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=in_chs, out_channels=out_chs,
                      stride=strides, padding=1, kernel_size=3, bias=False),
            nn.BatchNorm2d(out_chs),
            nn.ReLU(True)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=out_chs, out_channels=out_chs,
                      stride=1, padding=1, kernel_size=3, bias=False),
            nn.BatchNorm2d(out_chs)
        )

        if in_chs != out_chs:
            self.id_mapping = nn.Sequential(
                nn.Conv2d(in_channels=in_chs, out_channels=out_chs,
                          stride=strides, padding=0, kernel_size=1, bias=False),
                nn.BatchNorm2d(out_chs))
        else:
            self.id_mapping = None
        self.final_activation = nn.ReLU(True)

    def forward(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        if self.id_mapping is not None:
            x_ = self.id_mapping(x)
        else:
            x_ = x
        return self.final_activation(x_ + out)

class ResNetCIFAR(nn.Module):
    def __init__(self, num_layers=20, num_stem_conv=32, config=(16, 32, 64)):
        super(ResNetCIFAR, self).__init__()
        self.num_layers = 20
        self.head_conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=num_stem_conv,
                      stride=1, padding=1, kernel_size=3, bias=False),
            nn.BatchNorm2d(num_stem_conv),
            nn.ReLU(True)
        )
        num_layers_per_stage = (num_layers - 2) // 6
        self.body_op = []
        num_inputs = num_stem_conv
        for i in range(len(config)):
            for j in range(num_layers_per_stage):
                if j == 0 and i != 0:
                    strides = 2
                else:
                    strides = 1
                self.body_op.append(ResNet_Block(num_inputs, config[i], strides))
                num_inputs = config[i]
        self.body_op = nn.Sequential(*self.body_op)
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.final_fc = nn.Linear(config[-1], 10)

    def forward(self, x):
        out = self.head_conv(x)
        out = self.body_op(out)
        self.features = self.avg_pool(out)
        self.feat_1d = self.features.mean(3).mean(2)
        return self.final_fc(self.feat_1d)

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms


#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
#############################################

# %% [markdown]
# **Answer**
#
#
# ToTensor() and Normalize() is enough in this question. ToTensor() transforms PIL images to torch.tensor, and the element's value will be in [0,1]. Normalize() normalizes the tensor to have zero mean and unit standard deviation.

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=TRAIN_BATCH_SIZE, # your code
    shuffle=True, # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=VAL_BATCH_SIZE, # your code
    shuffle=False, # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F21.zip
# Extracting ./data/cifar10_trainval_F21.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F21.zip
# Extracting ./data/cifar10_trainval_F21.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here

device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = ResNetCIFAR()
net = net.to(device)
if device == 'cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
    
#############################################
# Out:
# Train on GPU...

# %% [markdown]
# ## Step 4: Set up loss functions and Optimizers
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**. Be careful about the required inputs to the loss function. Are the inputs the logits or softmax probabilities?)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 5e-4

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(params=net.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
# Training a neural network usually repeats the following 3 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the output logits from the neural network. Compute the forward loss.**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 200

# learning rate decay policy
DECAY_EPOCHS = [100, 150]
DECAY = 0.1

# the folder where the trained model is saved
CHECKPOINT_PATH = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    # handle the learning rate scheduler.
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################
    
    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        train_loss += loss.item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            
            # count the number of correctly predicted samples in the current batch
            _, predicted = outputs.max(1)
            total_examples += predicted.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'resnet_new.h5'))
        
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.6946, Training accuracy: 0.3594
# Validation loss: 1.5688, Validation accuracy: 0.4432
# Saving ...
#
# Epoch 1:
# Training loss: 1.2210, Training accuracy: 0.5572
# Validation loss: 1.2074, Validation accuracy: 0.5874
# Saving ...
#
# Epoch 2:
# Training loss: 0.9859, Training accuracy: 0.6499
# Validation loss: 1.0189, Validation accuracy: 0.6416
# Saving ...
#
# Epoch 3:
# Training loss: 0.8511, Training accuracy: 0.7019
# Validation loss: 1.1038, Validation accuracy: 0.6364
#
# Epoch 4:
# Training loss: 0.7512, Training accuracy: 0.7390
# Validation loss: 0.8278, Validation accuracy: 0.7106
# Saving ...
#
# Epoch 5:
# Training loss: 0.6946, Training accuracy: 0.7568
# Validation loss: 0.8595, Validation accuracy: 0.7176
# Saving ...
#
# Epoch 6:
# Training loss: 0.6602, Training accuracy: 0.7720
# Validation loss: 0.7280, Validation accuracy: 0.7510
# Saving ...
#
# Epoch 7:
# Training loss: 0.6268, Training accuracy: 0.7820
# Validation loss: 0.9901, Validation accuracy: 0.6916
#
# Epoch 8:
# Training loss: 0.6038, Training accuracy: 0.7925
# Validation loss: 0.9285, Validation accuracy: 0.6960
#
# Epoch 9:
# Training loss: 0.5827, Training accuracy: 0.7983
# Validation loss: 0.6381, Validation accuracy: 0.7808
# Saving ...
#
# Epoch 10:
# Training loss: 0.5812, Training accuracy: 0.7998
# Validation loss: 0.8518, Validation accuracy: 0.7390
#
# Epoch 11:
# Training loss: 0.5578, Training accuracy: 0.8090
# Validation loss: 0.6227, Validation accuracy: 0.7888
# Saving ...
#
# Epoch 12:
# Training loss: 0.5438, Training accuracy: 0.8132
# Validation loss: 0.6969, Validation accuracy: 0.7634
#
# Epoch 13:
# Training loss: 0.5372, Training accuracy: 0.8144
# Validation loss: 0.9625, Validation accuracy: 0.6930
#
# Epoch 14:
# Training loss: 0.5287, Training accuracy: 0.8178
# Validation loss: 0.7120, Validation accuracy: 0.7736
#
# Epoch 15:
# Training loss: 0.5276, Training accuracy: 0.8186
# Validation loss: 0.8146, Validation accuracy: 0.7438
#
# Epoch 16:
# Training loss: 0.5142, Training accuracy: 0.8229
# Validation loss: 0.7310, Validation accuracy: 0.7640
#
# Epoch 17:
# Training loss: 0.5071, Training accuracy: 0.8254
# Validation loss: 0.7132, Validation accuracy: 0.7588
#
# Epoch 18:
# Training loss: 0.5005, Training accuracy: 0.8278
# Validation loss: 0.8373, Validation accuracy: 0.7336
#
# Epoch 19:
# Training loss: 0.5003, Training accuracy: 0.8265
# Validation loss: 0.7428, Validation accuracy: 0.7648
#
# Epoch 20:
# Training loss: 0.5016, Training accuracy: 0.8271
# Validation loss: 0.7372, Validation accuracy: 0.7566
#
# Epoch 21:
# Training loss: 0.4921, Training accuracy: 0.8302
# Validation loss: 0.7094, Validation accuracy: 0.7652
#
# Epoch 22:
# Training loss: 0.4918, Training accuracy: 0.8326
# Validation loss: 0.6686, Validation accuracy: 0.7800
#
# Epoch 23:
# Training loss: 0.4887, Training accuracy: 0.8301
# Validation loss: 0.7250, Validation accuracy: 0.7644
#
# Epoch 24:
# Training loss: 0.4775, Training accuracy: 0.8331
# Validation loss: 0.8712, Validation accuracy: 0.7324
#
# Epoch 25:
# Training loss: 0.4820, Training accuracy: 0.8347
# Validation loss: 0.5507, Validation accuracy: 0.8144
# Saving ...
#
# Epoch 26:
# Training loss: 0.4734, Training accuracy: 0.8380
# Validation loss: 0.7289, Validation accuracy: 0.7674
#
# Epoch 27:
# Training loss: 0.4754, Training accuracy: 0.8356
# Validation loss: 0.7061, Validation accuracy: 0.7708
#
# Epoch 28:
# Training loss: 0.4721, Training accuracy: 0.8380
# Validation loss: 0.5650, Validation accuracy: 0.8114
#
# Epoch 29:
# Training loss: 0.4701, Training accuracy: 0.8388
# Validation loss: 0.7651, Validation accuracy: 0.7484
#
# Epoch 30:
# Training loss: 0.4629, Training accuracy: 0.8399
# Validation loss: 0.7592, Validation accuracy: 0.7616
#
# Epoch 31:
# Training loss: 0.4709, Training accuracy: 0.8397
# Validation loss: 0.5688, Validation accuracy: 0.8088
#
# Epoch 32:
# Training loss: 0.4605, Training accuracy: 0.8412
# Validation loss: 0.9104, Validation accuracy: 0.7400
#
# Epoch 33:
# Training loss: 0.4595, Training accuracy: 0.8422
# Validation loss: 0.5960, Validation accuracy: 0.8006
#
# Epoch 34:
# Training loss: 0.4589, Training accuracy: 0.8415
# Validation loss: 1.0265, Validation accuracy: 0.7102
#
# Epoch 35:
# Training loss: 0.4580, Training accuracy: 0.8426
# Validation loss: 1.7218, Validation accuracy: 0.5826
#
# Epoch 36:
# Training loss: 0.4537, Training accuracy: 0.8444
# Validation loss: 0.7228, Validation accuracy: 0.7718
#
# Epoch 37:
# Training loss: 0.4547, Training accuracy: 0.8434
# Validation loss: 0.7228, Validation accuracy: 0.7658
#
# Epoch 38:
# Training loss: 0.4527, Training accuracy: 0.8437
# Validation loss: 0.5623, Validation accuracy: 0.8178
# Saving ...
#
# Epoch 39:
# Training loss: 0.4449, Training accuracy: 0.8469
# Validation loss: 0.5544, Validation accuracy: 0.8242
# Saving ...
#
# Epoch 40:
# Training loss: 0.4497, Training accuracy: 0.8444
# Validation loss: 1.0006, Validation accuracy: 0.7158
#
# Epoch 41:
# Training loss: 0.4489, Training accuracy: 0.8442
# Validation loss: 0.6939, Validation accuracy: 0.7722
#
# Epoch 42:
# Training loss: 0.4439, Training accuracy: 0.8467
# Validation loss: 0.7604, Validation accuracy: 0.7666
#
# Epoch 43:
# Training loss: 0.4409, Training accuracy: 0.8484
# Validation loss: 0.5956, Validation accuracy: 0.7978
#
# Epoch 44:
# Training loss: 0.4416, Training accuracy: 0.8496
# Validation loss: 0.9262, Validation accuracy: 0.7134
#
# Epoch 45:
# Training loss: 0.4377, Training accuracy: 0.8484
# Validation loss: 0.6544, Validation accuracy: 0.7884
#
# Epoch 46:
# Training loss: 0.4439, Training accuracy: 0.8474
# Validation loss: 0.6045, Validation accuracy: 0.8114
#
# Epoch 47:
# Training loss: 0.4421, Training accuracy: 0.8482
# Validation loss: 0.6339, Validation accuracy: 0.7928
#
# Epoch 48:
# Training loss: 0.4311, Training accuracy: 0.8515
# Validation loss: 0.6325, Validation accuracy: 0.8026
#
# Epoch 49:
# Training loss: 0.4370, Training accuracy: 0.8519
# Validation loss: 0.6155, Validation accuracy: 0.8002
#
# Epoch 50:
# Training loss: 0.4315, Training accuracy: 0.8509
# Validation loss: 0.8094, Validation accuracy: 0.7510
#
# Epoch 51:
# Training loss: 0.4401, Training accuracy: 0.8466
# Validation loss: 0.7533, Validation accuracy: 0.7560
#
# Epoch 52:
# Training loss: 0.4357, Training accuracy: 0.8501
# Validation loss: 0.5606, Validation accuracy: 0.8096
#
# Epoch 53:
# Training loss: 0.4321, Training accuracy: 0.8494
# Validation loss: 0.5378, Validation accuracy: 0.8230
#
# Epoch 54:
# Training loss: 0.4320, Training accuracy: 0.8514
# Validation loss: 0.6372, Validation accuracy: 0.7844
#
# Epoch 55:
# Training loss: 0.4315, Training accuracy: 0.8506
# Validation loss: 0.6263, Validation accuracy: 0.7954
#
# Epoch 56:
# Training loss: 0.4251, Training accuracy: 0.8530
# Validation loss: 0.5740, Validation accuracy: 0.8060
#
# Epoch 57:
# Training loss: 0.4368, Training accuracy: 0.8486
# Validation loss: 0.5900, Validation accuracy: 0.8162
#
# Epoch 58:
# Training loss: 0.4273, Training accuracy: 0.8537
# Validation loss: 0.6537, Validation accuracy: 0.7912
#
# Epoch 59:
# Training loss: 0.4329, Training accuracy: 0.8509
# Validation loss: 1.0109, Validation accuracy: 0.7152
#
# Epoch 60:
# Training loss: 0.4206, Training accuracy: 0.8558
# Validation loss: 1.0859, Validation accuracy: 0.7222
#
# Epoch 61:
# Training loss: 0.4339, Training accuracy: 0.8503
# Validation loss: 0.6159, Validation accuracy: 0.7992
#
# Epoch 62:
# Training loss: 0.4264, Training accuracy: 0.8520
# Validation loss: 0.6265, Validation accuracy: 0.7970
#
# Epoch 63:
# Training loss: 0.4288, Training accuracy: 0.8529
# Validation loss: 0.6867, Validation accuracy: 0.7760
#
# Epoch 64:
# Training loss: 0.4278, Training accuracy: 0.8523
# Validation loss: 0.6614, Validation accuracy: 0.7830
#
# Epoch 65:
# Training loss: 0.4246, Training accuracy: 0.8538
# Validation loss: 0.5433, Validation accuracy: 0.8186
#
# Epoch 66:
# Training loss: 0.4324, Training accuracy: 0.8501
# Validation loss: 0.5646, Validation accuracy: 0.8142
#
# Epoch 67:
# Training loss: 0.4260, Training accuracy: 0.8541
# Validation loss: 0.6306, Validation accuracy: 0.7850
#
# Epoch 68:
# Training loss: 0.4203, Training accuracy: 0.8573
# Validation loss: 0.6024, Validation accuracy: 0.8060
#
# Epoch 69:
# Training loss: 0.4241, Training accuracy: 0.8542
# Validation loss: 0.7425, Validation accuracy: 0.7632
#
# Epoch 70:
# Training loss: 0.4266, Training accuracy: 0.8523
# Validation loss: 0.7388, Validation accuracy: 0.7662
#
# Epoch 71:
# Training loss: 0.4216, Training accuracy: 0.8539
# Validation loss: 0.6640, Validation accuracy: 0.7890
#
# Epoch 72:
# Training loss: 0.4276, Training accuracy: 0.8541
# Validation loss: 0.6135, Validation accuracy: 0.7976
#
# Epoch 73:
# Training loss: 0.4233, Training accuracy: 0.8551
# Validation loss: 0.4871, Validation accuracy: 0.8418
# Saving ...
#
# Epoch 74:
# Training loss: 0.4249, Training accuracy: 0.8546
# Validation loss: 0.5621, Validation accuracy: 0.8196
#
# Epoch 75:
# Training loss: 0.4222, Training accuracy: 0.8560
# Validation loss: 0.5247, Validation accuracy: 0.8294
#
# Epoch 76:
# Training loss: 0.4198, Training accuracy: 0.8558
# Validation loss: 0.6451, Validation accuracy: 0.7938
#
# Epoch 77:
# Training loss: 0.4235, Training accuracy: 0.8552
# Validation loss: 0.5320, Validation accuracy: 0.8274
#
# Epoch 78:
# Training loss: 0.4204, Training accuracy: 0.8560
# Validation loss: 0.6448, Validation accuracy: 0.7844
#
# Epoch 79:
# Training loss: 0.4223, Training accuracy: 0.8561
# Validation loss: 0.5948, Validation accuracy: 0.7934
#
# Epoch 80:
# Training loss: 0.4206, Training accuracy: 0.8574
# Validation loss: 0.6101, Validation accuracy: 0.8074
#
# Epoch 81:
# Training loss: 0.4158, Training accuracy: 0.8573
# Validation loss: 0.5386, Validation accuracy: 0.8170
#
# Epoch 82:
# Training loss: 0.4175, Training accuracy: 0.8563
# Validation loss: 0.7796, Validation accuracy: 0.7528
#
# Epoch 83:
# Training loss: 0.4144, Training accuracy: 0.8572
# Validation loss: 0.5764, Validation accuracy: 0.8150
#
# Epoch 84:
# Training loss: 0.4198, Training accuracy: 0.8566
# Validation loss: 0.7562, Validation accuracy: 0.7758
#
# Epoch 85:
# Training loss: 0.4189, Training accuracy: 0.8558
# Validation loss: 0.7171, Validation accuracy: 0.7762
#
# Epoch 86:
# Training loss: 0.4174, Training accuracy: 0.8565
# Validation loss: 0.5752, Validation accuracy: 0.8146
#
# Epoch 87:
# Training loss: 0.4105, Training accuracy: 0.8604
# Validation loss: 0.5223, Validation accuracy: 0.8236
#
# Epoch 88:
# Training loss: 0.4113, Training accuracy: 0.8588
# Validation loss: 0.5923, Validation accuracy: 0.7998
#
# Epoch 89:
# Training loss: 0.4221, Training accuracy: 0.8539
# Validation loss: 1.0023, Validation accuracy: 0.7264
#
# Epoch 90:
# Training loss: 0.4129, Training accuracy: 0.8584
# Validation loss: 0.7352, Validation accuracy: 0.7768
#
# Epoch 91:
# Training loss: 0.4119, Training accuracy: 0.8580
# Validation loss: 0.5741, Validation accuracy: 0.8110
#
# Epoch 92:
# Training loss: 0.4179, Training accuracy: 0.8566
# Validation loss: 0.5726, Validation accuracy: 0.8192
#
# Epoch 93:
# Training loss: 0.4169, Training accuracy: 0.8559
# Validation loss: 0.7611, Validation accuracy: 0.7604
#
# Epoch 94:
# Training loss: 0.4164, Training accuracy: 0.8563
# Validation loss: 0.6596, Validation accuracy: 0.7790
#
# Epoch 95:
# Training loss: 0.4126, Training accuracy: 0.8584
# Validation loss: 0.5379, Validation accuracy: 0.8222
#
# Epoch 96:
# Training loss: 0.4165, Training accuracy: 0.8577
# Validation loss: 0.5202, Validation accuracy: 0.8266
#
# Epoch 97:
# Training loss: 0.4128, Training accuracy: 0.8586
# Validation loss: 0.6827, Validation accuracy: 0.7824
#
# Epoch 98:
# Training loss: 0.4162, Training accuracy: 0.8583
# Validation loss: 0.5314, Validation accuracy: 0.8192
#
# Epoch 99:
# Training loss: 0.4179, Training accuracy: 0.8577
# Validation loss: 0.8807, Validation accuracy: 0.7512
#
# Current learning rate has decayed to 0.010000
# Epoch 100:
# Training loss: 0.2701, Training accuracy: 0.9094
# Validation loss: 0.2909, Validation accuracy: 0.9002
# Saving ...
#
# Epoch 101:
# Training loss: 0.2204, Training accuracy: 0.9251
# Validation loss: 0.2812, Validation accuracy: 0.9086
# Saving ...
#
# Epoch 102:
# Training loss: 0.1989, Training accuracy: 0.9315
# Validation loss: 0.2852, Validation accuracy: 0.9082
#
# Epoch 103:
# Training loss: 0.1902, Training accuracy: 0.9354
# Validation loss: 0.2822, Validation accuracy: 0.9092
# Saving ...
#
# Epoch 104:
# Training loss: 0.1801, Training accuracy: 0.9393
# Validation loss: 0.2809, Validation accuracy: 0.9090
#
# Epoch 105:
# Training loss: 0.1697, Training accuracy: 0.9428
# Validation loss: 0.2717, Validation accuracy: 0.9150
# Saving ...
#
# Epoch 106:
# Training loss: 0.1625, Training accuracy: 0.9458
# Validation loss: 0.2839, Validation accuracy: 0.9120
#
# Epoch 107:
# Training loss: 0.1594, Training accuracy: 0.9462
# Validation loss: 0.2751, Validation accuracy: 0.9138
#
# Epoch 108:
# Training loss: 0.1520, Training accuracy: 0.9476
# Validation loss: 0.2922, Validation accuracy: 0.9068
#
# Epoch 109:
# Training loss: 0.1488, Training accuracy: 0.9487
# Validation loss: 0.2927, Validation accuracy: 0.9070
#
# Epoch 110:
# Training loss: 0.1434, Training accuracy: 0.9513
# Validation loss: 0.2836, Validation accuracy: 0.9116
#
# Epoch 111:
# Training loss: 0.1383, Training accuracy: 0.9534
# Validation loss: 0.2831, Validation accuracy: 0.9122
#
# Epoch 112:
# Training loss: 0.1358, Training accuracy: 0.9539
# Validation loss: 0.2834, Validation accuracy: 0.9134
#
# Epoch 113:
# Training loss: 0.1343, Training accuracy: 0.9543
# Validation loss: 0.2913, Validation accuracy: 0.9104
#
# Epoch 114:
# Training loss: 0.1285, Training accuracy: 0.9568
# Validation loss: 0.3040, Validation accuracy: 0.9054
#
# Epoch 115:
# Training loss: 0.1268, Training accuracy: 0.9562
# Validation loss: 0.3070, Validation accuracy: 0.9076
#
# Epoch 116:
# Training loss: 0.1243, Training accuracy: 0.9576
# Validation loss: 0.2916, Validation accuracy: 0.9112
#
# Epoch 117:
# Training loss: 0.1262, Training accuracy: 0.9570
# Validation loss: 0.3126, Validation accuracy: 0.9016
#
# Epoch 118:
# Training loss: 0.1191, Training accuracy: 0.9593
# Validation loss: 0.3066, Validation accuracy: 0.9052
#
# Epoch 119:
# Training loss: 0.1194, Training accuracy: 0.9600
# Validation loss: 0.2912, Validation accuracy: 0.9094
#
# Epoch 120:
# Training loss: 0.1195, Training accuracy: 0.9593
# Validation loss: 0.2923, Validation accuracy: 0.9072
#
# Epoch 121:
# Training loss: 0.1197, Training accuracy: 0.9594
# Validation loss: 0.3006, Validation accuracy: 0.9088
#
# Epoch 122:
# Training loss: 0.1152, Training accuracy: 0.9607
# Validation loss: 0.3233, Validation accuracy: 0.9014
#
# Epoch 123:
# Training loss: 0.1146, Training accuracy: 0.9607
# Validation loss: 0.3138, Validation accuracy: 0.9046
#
# Epoch 124:
# Training loss: 0.1162, Training accuracy: 0.9599
# Validation loss: 0.3264, Validation accuracy: 0.9012
#
# Epoch 125:
# Training loss: 0.1189, Training accuracy: 0.9579
# Validation loss: 0.3249, Validation accuracy: 0.9024
#
# Epoch 126:
# Training loss: 0.1175, Training accuracy: 0.9607
# Validation loss: 0.3125, Validation accuracy: 0.9080
#
# Epoch 127:
# Training loss: 0.1210, Training accuracy: 0.9578
# Validation loss: 0.3301, Validation accuracy: 0.9044
#
# Epoch 128:
# Training loss: 0.1169, Training accuracy: 0.9596
# Validation loss: 0.3530, Validation accuracy: 0.8978
#
# Epoch 129:
# Training loss: 0.1190, Training accuracy: 0.9581
# Validation loss: 0.3169, Validation accuracy: 0.9004
#
# Epoch 130:
# Training loss: 0.1178, Training accuracy: 0.9600
# Validation loss: 0.2982, Validation accuracy: 0.9054
#
# Epoch 131:
# Training loss: 0.1193, Training accuracy: 0.9599
# Validation loss: 0.3472, Validation accuracy: 0.8924
#
# Epoch 132:
# Training loss: 0.1203, Training accuracy: 0.9586
# Validation loss: 0.3524, Validation accuracy: 0.8950
#
# Epoch 133:
# Training loss: 0.1223, Training accuracy: 0.9573
# Validation loss: 0.3338, Validation accuracy: 0.8998
#
# Epoch 134:
# Training loss: 0.1234, Training accuracy: 0.9570
# Validation loss: 0.3226, Validation accuracy: 0.9028
#
# Epoch 135:
# Training loss: 0.1178, Training accuracy: 0.9588
# Validation loss: 0.3421, Validation accuracy: 0.9000
#
# Epoch 136:
# Training loss: 0.1144, Training accuracy: 0.9606
# Validation loss: 0.3211, Validation accuracy: 0.9002
#
# Epoch 137:
# Training loss: 0.1165, Training accuracy: 0.9600
# Validation loss: 0.3560, Validation accuracy: 0.8964
#
# Epoch 138:
# Training loss: 0.1238, Training accuracy: 0.9568
# Validation loss: 0.3533, Validation accuracy: 0.8966
#
# Epoch 139:
# Training loss: 0.1194, Training accuracy: 0.9578
# Validation loss: 0.3373, Validation accuracy: 0.8978
#
# Epoch 140:
# Training loss: 0.1171, Training accuracy: 0.9589
# Validation loss: 0.3390, Validation accuracy: 0.8970
#
# Epoch 141:
# Training loss: 0.1185, Training accuracy: 0.9591
# Validation loss: 0.3666, Validation accuracy: 0.8874
#
# Epoch 142:
# Training loss: 0.1138, Training accuracy: 0.9610
# Validation loss: 0.3566, Validation accuracy: 0.8918
#
# Epoch 143:
# Training loss: 0.1173, Training accuracy: 0.9598
# Validation loss: 0.3236, Validation accuracy: 0.9004
#
# Epoch 144:
# Training loss: 0.1251, Training accuracy: 0.9572
# Validation loss: 0.4786, Validation accuracy: 0.8662
#
# Epoch 145:
# Training loss: 0.1169, Training accuracy: 0.9598
# Validation loss: 0.3729, Validation accuracy: 0.8896
#
# Epoch 146:
# Training loss: 0.1197, Training accuracy: 0.9588
# Validation loss: 0.3505, Validation accuracy: 0.8958
#
# Epoch 147:
# Training loss: 0.1214, Training accuracy: 0.9588
# Validation loss: 0.3472, Validation accuracy: 0.8998
#
# Epoch 148:
# Training loss: 0.1199, Training accuracy: 0.9581
# Validation loss: 0.3430, Validation accuracy: 0.8974
#
# Epoch 149:
# Training loss: 0.1187, Training accuracy: 0.9588
# Validation loss: 0.3167, Validation accuracy: 0.9034
#
# Current learning rate has decayed to 0.001000
# Epoch 150:
# Training loss: 0.0769, Training accuracy: 0.9759
# Validation loss: 0.2618, Validation accuracy: 0.9232
# Saving ...
#
# Epoch 151:
# Training loss: 0.0618, Training accuracy: 0.9814
# Validation loss: 0.2604, Validation accuracy: 0.9234
# Saving ...
#
# Epoch 152:
# Training loss: 0.0554, Training accuracy: 0.9841
# Validation loss: 0.2630, Validation accuracy: 0.9244
# Saving ...
#
# Epoch 153:
# Training loss: 0.0521, Training accuracy: 0.9854
# Validation loss: 0.2634, Validation accuracy: 0.9234
#
# Epoch 154:
# Training loss: 0.0495, Training accuracy: 0.9862
# Validation loss: 0.2622, Validation accuracy: 0.9246
# Saving ...
#
# Epoch 155:
# Training loss: 0.0486, Training accuracy: 0.9865
# Validation loss: 0.2624, Validation accuracy: 0.9256
# Saving ...
#
# Epoch 156:
# Training loss: 0.0453, Training accuracy: 0.9878
# Validation loss: 0.2671, Validation accuracy: 0.9218
#
# Epoch 157:
# Training loss: 0.0439, Training accuracy: 0.9884
# Validation loss: 0.2640, Validation accuracy: 0.9246
#
# Epoch 158:
# Training loss: 0.0415, Training accuracy: 0.9889
# Validation loss: 0.2684, Validation accuracy: 0.9232
#
# Epoch 159:
# Training loss: 0.0408, Training accuracy: 0.9892
# Validation loss: 0.2723, Validation accuracy: 0.9252
#
# Epoch 160:
# Training loss: 0.0393, Training accuracy: 0.9902
# Validation loss: 0.2713, Validation accuracy: 0.9242
#
# Epoch 161:
# Training loss: 0.0374, Training accuracy: 0.9910
# Validation loss: 0.2790, Validation accuracy: 0.9212
#
# Epoch 162:
# Training loss: 0.0382, Training accuracy: 0.9903
# Validation loss: 0.2766, Validation accuracy: 0.9212
#
# Epoch 163:
# Training loss: 0.0377, Training accuracy: 0.9903
# Validation loss: 0.2759, Validation accuracy: 0.9228
#
# Epoch 164:
# Training loss: 0.0358, Training accuracy: 0.9916
# Validation loss: 0.2731, Validation accuracy: 0.9212
#
# Epoch 165:
# Training loss: 0.0345, Training accuracy: 0.9923
# Validation loss: 0.2763, Validation accuracy: 0.9218
#
# Epoch 166:
# Training loss: 0.0351, Training accuracy: 0.9915
# Validation loss: 0.2829, Validation accuracy: 0.9222
#
# Epoch 167:
# Training loss: 0.0326, Training accuracy: 0.9923
# Validation loss: 0.2791, Validation accuracy: 0.9204
#
# Epoch 168:
# Training loss: 0.0333, Training accuracy: 0.9917
# Validation loss: 0.2806, Validation accuracy: 0.9208
#
# Epoch 169:
# Training loss: 0.0322, Training accuracy: 0.9924
# Validation loss: 0.2768, Validation accuracy: 0.9204
#
# Epoch 170:
# Training loss: 0.0320, Training accuracy: 0.9925
# Validation loss: 0.2772, Validation accuracy: 0.9202
#
# Epoch 171:
# Training loss: 0.0316, Training accuracy: 0.9926
# Validation loss: 0.2752, Validation accuracy: 0.9216
#
# Epoch 172:
# Training loss: 0.0311, Training accuracy: 0.9928
# Validation loss: 0.2814, Validation accuracy: 0.9216
#
# Epoch 173:
# Training loss: 0.0306, Training accuracy: 0.9931
# Validation loss: 0.2815, Validation accuracy: 0.9240
#
# Epoch 174:
# Training loss: 0.0302, Training accuracy: 0.9926
# Validation loss: 0.2791, Validation accuracy: 0.9202
#
# Epoch 175:
# Training loss: 0.0291, Training accuracy: 0.9936
# Validation loss: 0.2801, Validation accuracy: 0.9212
#
# Epoch 176:
# Training loss: 0.0304, Training accuracy: 0.9928
# Validation loss: 0.2806, Validation accuracy: 0.9216
#
# Epoch 177:
# Training loss: 0.0283, Training accuracy: 0.9935
# Validation loss: 0.2783, Validation accuracy: 0.9234
#
# Epoch 178:
# Training loss: 0.0299, Training accuracy: 0.9931
# Validation loss: 0.2823, Validation accuracy: 0.9236
#
# Epoch 179:
# Training loss: 0.0285, Training accuracy: 0.9937
# Validation loss: 0.2850, Validation accuracy: 0.9226
#
# Epoch 180:
# Training loss: 0.0293, Training accuracy: 0.9930
# Validation loss: 0.2887, Validation accuracy: 0.9222
#
# Epoch 181:
# Training loss: 0.0271, Training accuracy: 0.9939
# Validation loss: 0.2833, Validation accuracy: 0.9224
#
# Epoch 182:
# Training loss: 0.0278, Training accuracy: 0.9942
# Validation loss: 0.2860, Validation accuracy: 0.9206
#
# Epoch 183:
# Training loss: 0.0275, Training accuracy: 0.9937
# Validation loss: 0.2860, Validation accuracy: 0.9210
#
# Epoch 184:
# Training loss: 0.0265, Training accuracy: 0.9942
# Validation loss: 0.2859, Validation accuracy: 0.9220
#
# Epoch 185:
# Training loss: 0.0259, Training accuracy: 0.9944
# Validation loss: 0.2876, Validation accuracy: 0.9214
#
# Epoch 186:
# Training loss: 0.0256, Training accuracy: 0.9950
# Validation loss: 0.2903, Validation accuracy: 0.9196
#
# Epoch 187:
# Training loss: 0.0252, Training accuracy: 0.9947
# Validation loss: 0.2875, Validation accuracy: 0.9222
#
# Epoch 188:
# Training loss: 0.0256, Training accuracy: 0.9946
# Validation loss: 0.2928, Validation accuracy: 0.9220
#
# Epoch 189:
# Training loss: 0.0252, Training accuracy: 0.9946
# Validation loss: 0.2872, Validation accuracy: 0.9194
#
# Epoch 190:
# Training loss: 0.0254, Training accuracy: 0.9943
# Validation loss: 0.2843, Validation accuracy: 0.9238
#
# Epoch 191:
# Training loss: 0.0235, Training accuracy: 0.9953
# Validation loss: 0.2863, Validation accuracy: 0.9234
#
# Epoch 192:
# Training loss: 0.0240, Training accuracy: 0.9954
# Validation loss: 0.2909, Validation accuracy: 0.9224
#
# Epoch 193:
# Training loss: 0.0240, Training accuracy: 0.9951
# Validation loss: 0.2898, Validation accuracy: 0.9218
#
# Epoch 194:
# Training loss: 0.0243, Training accuracy: 0.9945
# Validation loss: 0.2881, Validation accuracy: 0.9228
#
# Epoch 195:
# Training loss: 0.0240, Training accuracy: 0.9947
# Validation loss: 0.2938, Validation accuracy: 0.9210
#
# Epoch 196:
# Training loss: 0.0233, Training accuracy: 0.9949
# Validation loss: 0.2920, Validation accuracy: 0.9220
#
# Epoch 197:
# Training loss: 0.0231, Training accuracy: 0.9952
# Validation loss: 0.2915, Validation accuracy: 0.9238
#
# Epoch 198:
# Training loss: 0.0237, Training accuracy: 0.9948
# Validation loss: 0.2858, Validation accuracy: 0.9246
#
# Epoch 199:
# Training loss: 0.0219, Training accuracy: 0.9957
# Validation loss: 0.2906, Validation accuracy: 0.9242
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9256

# %% [markdown]
# ## Save predictions on test data

# %%
from tools.dataset import CIFAR10

net = ResNetCIFAR()
chkpnt = torch.load('./saved_model/resnet_new.h5')
net.load_state_dict(chkpnt['net'])
net.cuda()
net.eval()

test_set = CIFAR10(
    root=DATA_ROOT, 
    mode='test', 
    transform=transform_val
)

# do NOT shuffle your test data loader
# otherwise the order of samples will be messed up
# and your test accuracy is likely to drop to random guessing level
test_loader = DataLoader(
    test_set, batch_size=200, shuffle=False, num_workers=1)

results = []
with torch.no_grad():
    for x in test_loader:
        y = net(x.cuda()).argmax(1).cpu()
        results.append(y)
    
results = torch.cat(results)
if isinstance(results, torch.Tensor):
    results = results.cpu().numpy()
    
with open('predictions.csv', 'w') as fp:
    fp.write("Id,Label\n")
    for i in range(len(results)):
        fp.write("%d,%d\n" %(i, results[i]))
# Out:
# Downloading https://www.dropbox.com/s/7glaxqq5p8nmd66/cifar10_test_F21.zip?dl=1 to ./data/cifar10_test_F21.zip
# 0it [00:00, ?it/s]
# Extracting ./data/cifar10_test_F21.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Our baseline test acc
#
# **0.9183**

# %% [markdown]
# # Load Model

# %%
# the folder where the trained model is saved
CHECKPOINT_PATH = "./saved_model"

net = ResNetCIFAR()
net = net.to(device)
checkpoint = torch.load(os.path.join(CHECKPOINT_PATH, 'resnet_new.h5'))
net.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Test the model

# %%
# Validate on the validation dataset

# switch to eval mode
net.eval()

# this help you compute the validation accuracy
total_examples = 0
correct_examples = 0

val_loss = 0 # again, track the validation loss if you want

# disable gradient during validation, which can save GPU memory
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(val_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        val_loss += loss
        ####################################

avg_loss = val_loss / len(val_loader)
avg_acc = correct_examples / total_examples
print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
# Out:
# Validation loss: 0.2624, Validation accuracy: 0.9256
